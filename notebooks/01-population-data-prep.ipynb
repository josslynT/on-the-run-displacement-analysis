# %%
# Population Data Preparation

Cleans and reshapes the World Bank population data (df1) into the format
used by the BigQuery `int_populationdf1` view. Output feeds the mart layer.

# %%
import pandas as pd
import pandas_gbq

# %%
df = pd.read_csv("/content/48395bd9-a40c-48d9-8362-43bad97e69fd_Data.csv")

# %%
df
# Out:
#                                            Country Name Country Code  \
# 0                                           Afghanistan          AFG
# 1                                           Afghanistan          AFG
# 2                                           Afghanistan          AFG
# 3                                           Afghanistan          AFG
# 4                                           Afghanistan          AFG
# ...                                                 ...          ...
# 1330                                                NaN          NaN
# 1331                                                NaN          NaN
# 1332                                                NaN          NaN
# 1333  Data from database: Population estimates and p...          NaN
# 1334                           Last Updated: 04/27/2026          NaN
#
#              Series Name        Series Code 1990 [YR1990] 1991 [YR1991]  \
# ...

# %%
df = df.rename(columns= {'Country Name' : "CountryName",
                    'Country Code' : "CountryCode",
                    'Series Name' : "SeriesType",
                    'Series Code' : "SeriesCode",
                    '1990 [YR1990]' : "Y1990",
                    '1991 [YR1991]' : "Y1991",
                    '1992 [YR1992]' : "Y1992",
                    '1993 [YR1993]' : "Y1993",
                    '1994 [YR1994]' : "Y1994",
                    '1995 [YR1995]' : "Y1995",
                    '1996 [YR1996]' : "Y1996",
                    '1997 [YR1997]' : "Y1997",
                    '1998 [YR1998]' : "Y1998",
                    '1999 [YR1999]' : "Y1999",
                    '2000 [YR2000]' : "Y2000",
                    '2001 [YR2001]' : "Y2001",
                    '2002 [YR2002]' : "Y2002",
                    '2003 [YR2003]' : "Y2003",
                    '2004 [YR2004]' : "Y2004",
                    '2005 [YR2005]' : "Y2005",
                    '2006 [YR2006]' : "Y2006",
                    '2007 [YR2007]' : "Y2007",
                    '2008 [YR2008]' : "Y2008",
                    '2009 [YR2009]' : "Y2009",
                    '2010 [YR2010]' : "Y2010",
                    '2011 [YR2011]' : "Y2011",
                    '2012 [YR2012]' : "Y2012",
                    '2013 [YR2013]' : "Y2013",
                    '2014 [YR2014]' : "Y2014",
                    '2015 [YR2015]' : "Y2015",
                    '2016 [YR2016]' : "Y2016",
                    '2017 [YR2017]' : "Y2017",
                    '2018 [YR2018]' : "Y2018",
                    '2019 [YR2019]' : "Y2019",
                    '2020 [YR2020]' : "Y2020",
                    '2021 [YR2021]' : "Y2021",
                    '2022 [YR2022]' : "Y2022",
                    '2023 [YR2023]' : "Y2023",
                    '2024 [YR2024]' : "Y2024",
                    '2025 [YR2025]' : "Y2025",
                    '2026 [YR2026]' : "Y2026"
                    })

# %%
df
# Out:
#                                             CountryName CountryCode  \
# 0                                           Afghanistan         AFG
# 1                                           Afghanistan         AFG
# 2                                           Afghanistan         AFG
# 3                                           Afghanistan         AFG
# 4                                           Afghanistan         AFG
# ...                                                 ...         ...
# 1330                                                NaN         NaN
# 1331                                                NaN         NaN
# 1332                                                NaN         NaN
# 1333  Data from database: Population estimates and p...         NaN
# 1334                           Last Updated: 04/27/2026         NaN
#
#               SeriesType         SeriesCode     Y1990     Y1991     Y1992  \
# 0      Population, total        SP.POP.TOTL  12045660  12238879  13278974
# ...

# %%
df['CountryName'].unique()
# Out:
# array(['Afghanistan', 'Africa Eastern and Southern',
#        'Africa Western and Central', 'Albania', 'Algeria',
#        'American Samoa', 'Andorra', 'Angola', 'Antigua and Barbuda',
#        'Arab World', 'Argentina', 'Armenia', 'Aruba', 'Australia',
#        'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain', 'Bangladesh',
#        'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda',
#        'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana',
#        'Brazil', 'British Virgin Islands', 'Brunei Darussalam',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia',
#        'Cameroon', 'Canada', 'Caribbean small states', 'Cayman Islands',
#        'Central African Republic', 'Central Europe and the Baltics',
#        'Chad', 'Channel Islands', 'Chile', 'China', 'Colombia', 'Comoros',
#        'Congo, Dem. Rep.', 'Congo, Rep.', 'Costa Rica', "Cote d'Ivoire",
#        'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czechia', 'Denmark',
# ...

# %%
value_to_remove = ['Africa Eastern and Southern',
       'Africa Western and Central',
       'Arab World',
       'Caribbean small states',
       'Early-demographic dividend', 'East Asia & Pacific',
       'East Asia & Pacific (excluding high income)',
       'East Asia & Pacific (IDA & IBRD countries)',
       'Euro area',
       'Europe & Central Asia',
       'Europe & Central Asia (excluding high income)',
       'Europe & Central Asia (IDA & IBRD countries)', 'European Union',
       'Fragile and conflict affected situations',
       'Heavily indebted poor countries (HIPC)', 'High income',
       'IBRD only',
       'IDA & IBRD total', 'IDA blend', 'IDA only',
       'IDA total',
       'Late-demographic dividend',
       'Latin America & Caribbean',
       'Latin America & Caribbean (excluding high income)',
       'Latin America & the Caribbean (IDA & IBRD countries)',
       'Least developed countries: UN classification',
       'Low & middle income', 'Low income', 'Lower middle income',
       'Middle East, North Africa, Afghanistan & Pakistan',
       'Middle East, North Africa, Afghanistan & Pakistan (excluding high income)',
       'Middle East, North Africa, Afghanistan & Pakistan (IDA & IBRD)',
       'Middle income',
       'Not classified',
       'OECD members', 'Other small states',
       'Pacific island small states',
       'Post-demographic dividend',
       'Pre-demographic dividend',
       'Small states',
       'South Asia', 'South Asia (IDA & IBRD)',
       'Sub-Saharan Africa',
       'Sub-Saharan Africa (excluding high income)',
       'Sub-Saharan Africa (IDA & IBRD countries)',
       'Upper middle income',
       'World',
       'NaN', 'Data from database: Population estimates and projections',
       'Last Updated: 04/27/2026']

df1 = df[~df['CountryName'].isin(value_to_remove)] ### here we remove the row we dont need thats not country eg: we took away ''

# %%
df1
# Out:
#       CountryName CountryCode          SeriesType         SeriesCode  \
# 0     Afghanistan         AFG   Population, total        SP.POP.TOTL
# 1     Afghanistan         AFG    Rural population        SP.RUR.TOTL
# 2     Afghanistan         AFG    Urban population        SP.URB.TOTL
# 3     Afghanistan         AFG    Population, male  SP.POP.TOTL.MA.IN
# 4     Afghanistan         AFG  Population, female  SP.POP.TOTL.FE.IN
# ...           ...         ...                 ...                ...
# 1328     Zimbabwe         ZWE    Population, male  SP.POP.TOTL.MA.IN
# 1329     Zimbabwe         ZWE  Population, female  SP.POP.TOTL.FE.IN
# 1330          NaN         NaN                 NaN                NaN
# 1331          NaN         NaN                 NaN                NaN
# 1332          NaN         NaN                 NaN                NaN
#
#          Y1990     Y1991     Y1992     Y1993     Y1994     Y1995  ...  \
# ...

# %%
df1 = df1.dropna(subset=['CountryName'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1095 entries, 0 to 1329
# Data columns (total 41 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CountryName  1095 non-null   object
#  1   CountryCode  1095 non-null   object
#  2   SeriesType   1095 non-null   object
#  3   SeriesCode   1095 non-null   object
#  4   Y1990        1095 non-null   object
#  5   Y1991        1095 non-null   object
#  6   Y1992        1095 non-null   object
#  7   Y1993        1095 non-null   object
#  8   Y1994        1095 non-null   object
#  9   Y1995        1095 non-null   object
#  10  Y1996        1095 non-null   object
#  11  Y1997        1095 non-null   object
#  12  Y1998        1095 non-null   object
#  13  Y1999        1095 non-null   object
#  14  Y2000        1095 non-null   object
#  15  Y2001        1095 non-null   object
#  16  Y2002        1095 non-null   object
#  17  Y2003        1095 non-null   object
# ...

# %%
pandas_gbq.to_gbq(
    df1,
    destination_table="ontherun-499508.raw.populationdf1",  # project.dataset.new_table_name
    project_id="lewagon-bootcamp-494609",  # Use your own project ID, not the project owner's
    if_exists="replace")
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 10106.76it/s]
